# %%
# Import libraries

from citipy import citipy
import numpy as np
import pandas as pd
import gmaps

# %%
gkey = 'AIzaSyBib5QnZBPzqxGsbeM9suzPjXZM_pCeSVI'

# %%
filename = "../Part1/challenge_cities.csv"

# %%
city_data_df = pd.read_csv(filename)

# %%
city_data_df
# Out:
#      City_ID               City    Lat     Lng  Max Temp Current Description  \
# 0          0  Santiago De Chuco  -8.15  -78.18     49.73       broken clouds
# 1          1          Cape Town -33.93   18.42     62.01     overcast clouds
# 2          2             Galich  58.38   42.35     25.99    scattered clouds
# 3          3           Lorengau  -2.02  147.27     84.87          light rain
# 4          4               Hilo  19.73 -155.09     80.60    scattered clouds
# ..       ...                ...    ...     ...       ...                 ...
# 540      540          Oktyabrsk  49.47   57.42     37.98           clear sky
# 541      541    Port Hawkesbury  45.62  -61.35     37.00     overcast clouds
# 542      542      Leshukonskoye  64.90   45.76     20.82     overcast clouds
# 543      543        Belaya Gora  68.53  146.42     27.79           clear sky
# 544      544               Payo  -3.75  103.64     87.87     overcast clouds
#
# ...

# %%
min_temp = float(input("Enter minimum temperature preference: "))
# Out:
# Enter minimum temperature preference: 40

# %%
max_temp = float(input("Enter maximum temperature preference: "))
# Out:
# Enter maximum temperature preference: 80

# %%
raining = input("Do you want it to be raining? (yes/no)")
# Out:
# Do you want it to be raining? (yes/no)yes

# %%
snowing = input("Do you want it to be snowing? (yes/no)")
# Out:
# Do you want it to be snowing? (yes/no)no

# %%
# Narrow down cities that fit criteria
if raining == "no" and snowing == "no":
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp) &
                                       (city_data_df["Rain inches (last 3 hrs)"] == 0) &
                                         (city_data_df["Snow inches (last 3 hrs)"] == 0)]
    
elif raining == "no" and snowing == "yes":
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp) &
                                       (city_data_df["Rain inches (last 3 hrs)"] == 0) &
                                         (city_data_df["Snow inches (last 3 hrs)"] > 0.0)]
    
elif raining == "yes" and snowing == "no":
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp) &
                                       (city_data_df["Rain inches (last 3 hrs)"] > 0.0) &
                                         (city_data_df["Snow inches (last 3 hrs)"] == 0)]
    
else:
    filtered_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp) &
                                       (city_data_df["Rain inches (last 3 hrs)"] > 0.0) &
                                         (city_data_df["Snow inches (last 3 hrs)"] > 0)]

# %%
filtered_cities_df.head(10)
# Out:
#      City_ID             City    Lat     Lng  Max Temp Current Description  \
# 9          9          Gelemso   8.82   40.52     61.83          light rain
# 21        21        Busselton -33.65  115.33     69.01          light rain
# 22        22      Salinopolis  -0.61  -47.36     79.14          light rain
# 29        29  Bambous Virieux -20.34   57.76     75.99          light rain
# 33        33         Souillac -20.52   57.52     75.99          light rain
# 53        53           Makali   8.63  -11.67     69.96       moderate rain
# 60        60     Constitucion -35.33  -72.42     57.42       moderate rain
# 122      122        Athabasca  54.72 -113.29     44.89          light rain
# 139      139            Irbil  36.19   44.01     59.00          light rain
# 164      164             Lebu -37.62  -73.65     55.40          light rain
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)  Humidity  Cloudiness  \
# ...

# %%
filtered_cities_df.count()
# Out:
# City_ID                     42
# City                        42
# Lat                         42
# Lng                         42
# Max Temp                    42
# Current Description         42
# Rain inches (last 3 hrs)    42
# Snow inches (last 3 hrs)    42
# Humidity                    42
# Cloudiness                  42
# Wind Speed                  42
# Country                     42
# Date                        42
# dtype: int64

# %%
# Drop any empty rows and make a new DataFrame.
clean_travel_cities = filtered_cities_df.dropna()
clean_travel_cities.head()
# Out:
#     City_ID             City    Lat     Lng  Max Temp Current Description  \
# 9         9          Gelemso   8.82   40.52     61.83          light rain
# 21       21        Busselton -33.65  115.33     69.01          light rain
# 22       22      Salinopolis  -0.61  -47.36     79.14          light rain
# 29       29  Bambous Virieux -20.34   57.76     75.99          light rain
# 33       33         Souillac -20.52   57.52     75.99          light rain
#
#     Rain inches (last 3 hrs)  Snow inches (last 3 hrs)  Humidity  Cloudiness  \
# 9                       0.18                       0.0        51         100
# 21                      0.23                       0.0        52          26
# 22                      2.52                       0.0        82          98
# 29                      0.27                       0.0        89          37
# 33                      0.41                       0.0        89          66
#
#     Wind Speed Country                 Date
# ...

# %%
clean_travel_cities.count()
# Out:
# City_ID                     42
# City                        42
# Lat                         42
# Lng                         42
# Max Temp                    42
# Current Description         42
# Rain inches (last 3 hrs)    42
# Snow inches (last 3 hrs)    42
# Humidity                    42
# Cloudiness                  42
# Wind Speed                  42
# Country                     42
# Date                        42
# dtype: int64

# %%
clean_travel_cities.columns
# Out:
# Index(['City_ID', 'City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain inches (last 3 hrs)', 'Snow inches (last 3 hrs)', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                 City Country  Max Temp Current Description    Lat     Lng  \
# 9            Gelemso      ET     61.83          light rain   8.82   40.52
# 21         Busselton      AU     69.01          light rain -33.65  115.33
# 22       Salinopolis      BR     79.14          light rain  -0.61  -47.36
# 29   Bambous Virieux      MU     75.99          light rain -20.34   57.76
# 33          Souillac      MU     75.99          light rain -20.52   57.52
# 53            Makali      SL     69.96       moderate rain   8.63  -11.67
# 60      Constitucion      CL     57.42       moderate rain -35.33  -72.42
# 122        Athabasca      CA     44.89          light rain  54.72 -113.29
# 139            Irbil      IQ     59.00          light rain  36.19   44.01
# 164             Lebu      CL     55.40          light rain -37.62  -73.65
#
#     Hotel Name
# 9
# 21
# 22
# 29
# 33
# 53
# 60
# 122
# 139
# 164

# %%
import requests

# Set parameters to search for a hotel
params = {
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}

# Iterate through 
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Make request and get the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#                 City Country  Max Temp Current Description    Lat     Lng  \
# 9            Gelemso      ET     61.83          light rain   8.82   40.52
# 21         Busselton      AU     69.01          light rain -33.65  115.33
# 22       Salinopolis      BR     79.14          light rain  -0.61  -47.36
# 29   Bambous Virieux      MU     75.99          light rain -20.34   57.76
# 33          Souillac      MU     75.99          light rain -20.52   57.52
# 53            Makali      SL     69.96       moderate rain   8.63  -11.67
# 60      Constitucion      CL     57.42       moderate rain -35.33  -72.42
# 122        Athabasca      CA     44.89          light rain  54.72 -113.29
# 139            Irbil      IQ     59.00          light rain  36.19   44.01
# 164             Lebu      CL     55.40          light rain -37.62  -73.65
#
#                       Hotel Name
# 9                    Kerod Hotel
# 21       Observatory Guest House
# 22             Hotel Salinópolis
# ...

# %%
# Create the output File (CSV)
output_data_file = "vacation_cities.csv"
# Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Store csv created in part one into a DataFrame
vacation_df = pd.read_csv("vacation_cities.csv")
vacation_df.head()
# Out:
#    City_ID             City Country  Max Temp Current Description    Lat  \
# 0        9          Gelemso      ET     61.83          light rain   8.82
# 1       21        Busselton      AU     69.01          light rain -33.65
# 2       22      Salinopolis      BR     79.14          light rain  -0.61
# 3       29  Bambous Virieux      MU     75.99          light rain -20.34
# 4       33         Souillac      MU     75.99          light rain -20.52
#
#       Lng               Hotel Name
# 0   40.52              Kerod Hotel
# 1  115.33  Observatory Guest House
# 2  -47.36        Hotel Salinópolis
# 3   57.76           Casa Tia Villa
# 4   57.52              Bils' Villa

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]
locations = vacation_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
